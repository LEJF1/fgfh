# %%
import pandas as pd
import numpy as np
from pprint import pprint 
import codecs
import json
import glob 
pd.set_option('display.max_columns', None)
from pandas import json_normalize

# %%
path = 'Data'
file = glob.glob(path + "/*.json") ##считывание файла

# %% [markdown]
# удалить все кроме букв

# %%
file
# Out:
# ['Data\\Cybersport.Metaratings.json',
#  'Data\\ESforce Holding.json',
#  'Data\\Gett.json',
#  'Data\\Goose Gaming.json',
#  'Data\\MMA.Metaratings.json',
#  'Data\\skillbox.json',
#  'Data\\Vinci Agency.json',
#  'Data\\Гэллэри Сервис.json',
#  'Data\\Здоровье.ру.json',
#  'Data\\Иннотех.json',
#  'Data\\Проект по использованию технологий компьютерного зрения на базе искусственного интеллекта для анализа медицинских изображений.json',
#  'Data\\Промобот.json',
#  'Data\\Студия Артемия Лебедева.json',
#  'Data\\Федерация креативных индустрий.json']

# %%
with codecs.open('Data\\Cybersport.Metaratings.json', 'r', 'utf-8-sig') as json_file:  
        data = json.load(json_file)

# %%
data
# Out:
# {'info': None,
# ...

# %%
# самая простая токенизация: разбиение по пробелам

text = '''
7 декабря состоялась церемония награждения лауреатов премии Рунета 2021 года. В этом году на премию было подано 1097 работ за вклад в развитие российского сегмента сети интернет в девять основных и четыре специальные номинации. Финалистами конкурса в каждой номинации стали по 10 организаций. \n\r\nЛауреатами премии Рунета 2021 стали 52 компании и 3 персоны. Причем раньше организаторы (Российская ассоциация электронных коммуникаций — РАЭК) награждали несколько лучших представителей в каждой из номинации, по мнению экспертного сообщества. В этом году они обратились к помощи искусственного интеллекта и добавили еще одного лауреата, который выбирался именно по мнению ИИ. \n\r\nНоминация «Государство и Общество», победители:\n\n\n Благотворительный фонд «Подари жизнь»;\n АНО «Диалог»;\n Правительство Москвы, проект Цифровая экосистема Москвы;\n ФНС России;\n Программа «Пушкинская карта» / АО «Почта Банк».\n\r\nНоминация «СМИ и Массовые коммуникации»: \n\n\n Телеканал 360;\n Медиахолдинг Independent Media;\n АО «Коммерсантъ».\n\r\nНоминация “Образование и Кадры”:\n\n\n Правительство Москвы, проект “Московская электронная школа” (МЭШ);\n Проект программы “Сбер для детей и родителей” совместно с Rambler&Co;\n ООО “Цифровое образование”, проект ИКОП “Сферум”;\n Образовательная платформа “Нетология” (ООО “Нетология”);\n Компания Samsung Electronics.\n\r\nНоминация «Наука, технологии и инновации»:\n\n\n Gett;\n Иннотех;\n Skillbox ;\n Промобот;\n SberDevices ;\n Билайн.\n\r\nНоминация “Культурные проекты в Сети”:\n\n\n Общественное телевидение России;\n Проект “Путь героя” информационного агентства ТАСС и киностудии “Союзмультфильм”;\n Эмпатия Манучи (авторский канал Манучарова Вячеслава);\n Федеральное государственное бюджетное учреждение культуры «Всероссийское музейное объединение “Государственная Третьяковская галерея”.\n\r\nНоминация “Игровая индустрия и киберспорт”:\n\n\n Федерация компьютерного спорта города Москвы — “Московский Киберспорт”;\n ESforce Holding;\n Cybersport.Metaratings;\n MetaMMA;\n Goose Gaming.\n\r\nНоминация “Креативные индустрии”:\n\n\n Ассоциация профессиональных участников творческой экономики “Федерация креативных индустрий”;\n ООО “Гэллэри Сервис”;\n Vinci Agency;\n Проект по веб-инклюзии (Студия Артемия Лебедева).\n\r\nНоминация “Здоровье и медицина”:\n\n\n Здоровье.ру;\n Проект „Здоровое Питание“ (Федеральная служба по надзору в сфере защиты прав потребителей и благополучия человека);\n Правительство Москвы, проект по использованию технологий компьютерного зрения на базе искусственного интеллекта (ИИ) для анализа медицинских изображений.\n\r\nНоминация “Экономика и бизнес”:\n\n\n СберМаркет;\n Balance Platform;\n Московская биржа;\n Метарейтинг.\n\r\nНоминация “За развитие среднего и малого бизнеса в Рунете”: \n\n\n Портал для предпринимателей Smallbusiness.ru;\n ПАО „МТС“, проект “Знаем лично”;\n Банк ВТБ ПАО, проект интернет-банк.\n\r\nНоминация “#СЧАСТЬЕЕСТЬ”: Автономная некоммерческая организация по развитию экологических, социальных и патриотических проектов „Сад Памяти“.\n\r\nНоминация “Развитие внутреннего туризма”: \n\n\n Проект Oh My Град;\n Россия: 85 приключений, проект онлайн-медиа Russia Beyond, входящее в телесеть RT;\n АНО “Проектный офис по развитию туризма и гостеприимства Москвы” Туристический сервис RUSSPASS;\n Комитет по туризму города Москвы, проект Discovermoscow.com.\n\r\nНоминация “Открытые коммуникации”:\n\n\n Мэр Вологды — Сергей Воропанов;\n Правительство Тульской области;\n Федеральное агентство по туризму, портал Russia.travel.\n\r\nНародном голосовании премии Рунета 2021 были выбраны такие лауреаты: \n\n\n в номинации “КТО”: Дмитрий Спиридонов;\n в номинации “ЧТО”: Forza;\n в номинациилучший цифровой регион (номинация “Где”): город Москва.\n\r\nВдобавок за персональный многолетний вклад в развитие интернет-отрасли награду премия Рунета 2021 получил экс-глава Роспечати Михаил Сеславинский. \n\n\n\r\nВ этом году Хабр также подавал заявку на участие в премии Рунета в номинации «Креативные индустрии». Заявлен был наш конкурс «Технотекст». Мы не стали лауреатами, но вошли сперва в шорт-лист, а затем и в число финалистов рядом с очень серьёзными соперниками. Описание заявки Хабра можно посмотреть на странице сайта конкурса.
'''

tokens = text.split()
print(tokens)
len(tokens)
# Out:
# ['7', 'декабря', 'состоялась', 'церемония', 'награждения', 'лауреатов', 'премии', 'Рунета', '2021', 'года.', 'В', 'этом', 'году', 'на', 'премию', 'было', 'подано', '1097', 'работ', 'за', 'вклад', 'в', 'развитие', 'российского', 'сегмента', 'сети', 'интернет', 'в', 'девять', 'основных', 'и', 'четыре', 'специальные', 'номинации.', 'Финалистами', 'конкурса', 'в', 'каждой', 'номинации', 'стали', 'по', '10', 'организаций.', 'Лауреатами', 'премии', 'Рунета', '2021', 'стали', '52', 'компании', 'и', '3', 'персоны.', 'Причем', 'раньше', 'организаторы', '(Российская', 'ассоциация', 'электронных', 'коммуникаций', '—', 'РАЭК)', 'награждали', 'несколько', 'лучших', 'представителей', 'в', 'каждой', 'из', 'номинации,', 'по', 'мнению', 'экспертного', 'сообщества.', 'В', 'этом', 'году', 'они', 'обратились', 'к', 'помощи', 'искусственного', 'интеллекта', 'и', 'добавили', 'еще', 'одного', 'лауреата,', 'который', 'выбирался', 'именно', 'по', 'мнению', 'ИИ.', 'Номинация', '«Государство', 'и', 'Общество»,
# ...

# %%
 # !pip install --user nltk

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('snowball_data')
nltk.download('perluniprops')
nltk.download('universal_tagset')
nltk.download('stopwords')
nltk.download('nonbreaking_prefixes')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user.UIT\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user.UIT\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package snowball_data to
# [nltk_data]     C:\Users\user.UIT\AppData\Roaming\nltk_data...
# [nltk_data]   Package snowball_data is already up-to-date!
# [nltk_data] Downloading package perluniprops to
# [nltk_data]     C:\Users\user.UIT\AppData\Roaming\nltk_data...
# [nltk_data]   Package perluniprops is already up-to-date!
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\user.UIT\AppData\Roaming\nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user.UIT\AppData\Roaming\nltk_data...
# ...

# %%
from nltk.tokenize import word_tokenize, ToktokTokenizer

tokens = word_tokenize(text)
print(tokens)
len(tokens)
# Out:
# ['7', 'декабря', 'состоялась', 'церемония', 'награждения', 'лауреатов', 'премии', 'Рунета', '2021', 'года', '.', 'В', 'этом', 'году', 'на', 'премию', 'было', 'подано', '1097', 'работ', 'за', 'вклад', 'в', 'развитие', 'российского', 'сегмента', 'сети', 'интернет', 'в', 'девять', 'основных', 'и', 'четыре', 'специальные', 'номинации', '.', 'Финалистами', 'конкурса', 'в', 'каждой', 'номинации', 'стали', 'по', '10', 'организаций', '.', 'Лауреатами', 'премии', 'Рунета', '2021', 'стали', '52', 'компании', 'и', '3', 'персоны', '.', 'Причем', 'раньше', 'организаторы', '(', 'Российская', 'ассоциация', 'электронных', 'коммуникаций', '—', 'РАЭК', ')', 'награждали', 'несколько', 'лучших', 'представителей', 'в', 'каждой', 'из', 'номинации', ',', 'по', 'мнению', 'экспертного', 'сообщества', '.', 'В', 'этом', 'году', 'они', 'обратились', 'к', 'помощи', 'искусственного', 'интеллекта', 'и', 'добавили', 'еще', 'одного', 'лауреата', ',', 'который', 'выбирался', 'именно', 'по', 'мнению', 'ИИ', '.', 'Номи
# ...

# %%
# Способ №1
import re

# набор пунктуационных символов зависит от задачи и текста
punct = '!"#$%&()*\+,-\./:;<=>?@\[\]^_`{|}~„“«»†*\—/\-‘’1234567890”None'
clean_text = re.sub(punct, r'', text)
print(clean_text.split())
# Out:
# ['7', 'декабря', 'состоялась', 'церемония', 'награждения', 'лауреатов', 'премии', 'Рунета', '2021', 'года.', 'В', 'этом', 'году', 'на', 'премию', 'было', 'подано', '1097', 'работ', 'за', 'вклад', 'в', 'развитие', 'российского', 'сегмента', 'сети', 'интернет', 'в', 'девять', 'основных', 'и', 'четыре', 'специальные', 'номинации.', 'Финалистами', 'конкурса', 'в', 'каждой', 'номинации', 'стали', 'по', '10', 'организаций.', 'Лауреатами', 'премии', 'Рунета', '2021', 'стали', '52', 'компании', 'и', '3', 'персоны.', 'Причем', 'раньше', 'организаторы', '(Российская', 'ассоциация', 'электронных', 'коммуникаций', '—', 'РАЭК)', 'награждали', 'несколько', 'лучших', 'представителей', 'в', 'каждой', 'из', 'номинации,', 'по', 'мнению', 'экспертного', 'сообщества.', 'В', 'этом', 'году', 'они', 'обратились', 'к', 'помощи', 'искусственного', 'интеллекта', 'и', 'добавили', 'еще', 'одного', 'лауреата,', 'который', 'выбирался', 'именно', 'по', 'мнению', 'ИИ.', 'Номинация', '«Государство', 'и', 'Общество»,
# ...

# %%
clean_words = [w.strip(punct) for w in word_tokenize(text)]
print(clean_words)

clean_words == clean_text
# Out:
# ['', 'декабря', 'состоялась', 'церемония', 'награждения', 'лауреатов', 'премии', 'Рунета', '', 'года', '', 'В', 'этом', 'году', 'на', 'премию', 'было', 'подано', '', 'работ', 'за', 'вклад', 'в', 'развитие', 'российского', 'сегмента', 'сети', 'интернет', 'в', 'девять', 'основных', 'и', 'четыре', 'специальные', 'номинации', '', 'Финалистами', 'конкурса', 'в', 'каждой', 'номинации', 'стали', 'по', '', 'организаций', '', 'Лауреатами', 'премии', 'Рунета', '', 'стали', '', 'компании', 'и', '', 'персоны', '', 'Причем', 'раньше', 'организаторы', '', 'Российская', 'ассоциация', 'электронных', 'коммуникаций', '', 'РАЭК', '', 'награждали', 'несколько', 'лучших', 'представителей', 'в', 'каждой', 'из', 'номинации', '', 'по', 'мнению', 'экспертного', 'сообщества', '', 'В', 'этом', 'году', 'они', 'обратились', 'к', 'помощи', 'искусственного', 'интеллекта', 'и', 'добавили', 'еще', 'одного', 'лауреата', '', 'который', 'выбирался', 'именно', 'по', 'мнению', 'ИИ', '', 'Номинация', '', 'Государство', 'и
# ...

# %%
clean_words = [w.lower() for w in clean_words if w != '']
print(clean_words)
# Out:
# ['декабря', 'состоялась', 'церемония', 'награждения', 'лауреатов', 'премии', 'рунета', 'года', 'в', 'этом', 'году', 'на', 'премию', 'было', 'подано', 'работ', 'за', 'вклад', 'в', 'развитие', 'российского', 'сегмента', 'сети', 'интернет', 'в', 'девять', 'основных', 'и', 'четыре', 'специальные', 'номинации', 'финалистами', 'конкурса', 'в', 'каждой', 'номинации', 'стали', 'по', 'организаций', 'лауреатами', 'премии', 'рунета', 'стали', 'компании', 'и', 'персоны', 'причем', 'раньше', 'организаторы', 'российская', 'ассоциация', 'электронных', 'коммуникаций', 'раэк', 'награждали', 'несколько', 'лучших', 'представителей', 'в', 'каждой', 'из', 'номинации', 'по', 'мнению', 'экспертного', 'сообщества', 'в', 'этом', 'году', 'они', 'обратились', 'к', 'помощи', 'искусственного', 'интеллекта', 'и', 'добавили', 'еще', 'одного', 'лауреата', 'который', 'выбирался', 'именно', 'по', 'мнению', 'ии', 'номинация', 'государство', 'и', 'общество', 'победители', 'благотворительный', 'фонд', 'подари', 'жизнь',
# ...

# %%
from nltk.corpus import stopwords

# смотрим, какие языки есть
stopwords.fileids()
# Out:
# ['arabic',
#  'azerbaijani',
#  'basque',
#  'bengali',
#  'catalan',
#  'chinese',
#  'danish',
#  'dutch',
#  'english',
#  'finnish',
#  'french',
#  'german',
#  'greek',
#  'hebrew',
#  'hinglish',
#  'hungarian',
#  'indonesian',
#  'italian',
#  'kazakh',
#  'nepali',
#  'norwegian',
#  'portuguese',
#  'romanian',
#  'russian',
#  'slovene',
#  'spanish',
#  'swedish',
#  'tajik',
#  'turkish']

# %%
sw = stopwords.words('russian')
print(sw)
# Out:
# ['и', 'в', 'во', 'не', 'что', 'он', 'на', 'я', 'с', 'со', 'как', 'а', 'то', 'все', 'она', 'так', 'его', 'но', 'да', 'ты', 'к', 'у', 'же', 'вы', 'за', 'бы', 'по', 'только', 'ее', 'мне', 'было', 'вот', 'от', 'меня', 'еще', 'нет', 'о', 'из', 'ему', 'теперь', 'когда', 'даже', 'ну', 'вдруг', 'ли', 'если', 'уже', 'или', 'ни', 'быть', 'был', 'него', 'до', 'вас', 'нибудь', 'опять', 'уж', 'вам', 'ведь', 'там', 'потом', 'себя', 'ничего', 'ей', 'может', 'они', 'тут', 'где', 'есть', 'надо', 'ней', 'для', 'мы', 'тебя', 'их', 'чем', 'была', 'сам', 'чтоб', 'без', 'будто', 'чего', 'раз', 'тоже', 'себе', 'под', 'будет', 'ж', 'тогда', 'кто', 'этот', 'того', 'потому', 'этого', 'какой', 'совсем', 'ним', 'здесь', 'этом', 'один', 'почти', 'мой', 'тем', 'чтобы', 'нее', 'сейчас', 'были', 'куда', 'зачем', 'всех', 'никогда', 'можно', 'при', 'наконец', 'два', 'об', 'другой', 'хоть', 'после', 'над', 'больше', 'тот', 'через', 'эти', 'нас', 'про', 'всего', 'них', 'какая', 'много', 'разве', 'три', 'эту', 'моя', 'в
# ...

# %%
print([w if w not in sw else print(w) for w in clean_words])
# Out:
# в
# этом
# на
# было
# за
# в
# в
# и
# в
# по
# и
# в
# из
# по
# в
# этом
# они
# к
# и
# еще
# по
# и
# и
# и
# для
# и
# с
# и
# в
# и
# и
# по
# и
# по
# в
# и
# по
# на
# для
# и
# за
# и
# в
# для
# по
# и
# в
# по
# и
# по
# по
# были
# в
# кто
# в
# что
# в
# где
# за
# в
# в
# этом
# на
# в
# в
# был
# мы
# не
# но
# в
# а
# и
# в
# с
# можно
# на
# ...

# %%
tk = ['декабря', 'состоялась', 'церемония', 'награждения', 'лауреатов', 'премии', 'рунета', 'года', None, None, 'году', None, 'премию', None, 'подано', 'работ', None, 'вклад', None, 'развитие', 'российского', 'сегмента', 'сети', 'интернет', None, 'девять', 'основных', None, 'четыре', 'специальные', 'номинации', 'финалистами', 'конкурса', None, 'каждой', 'номинации', 'стали', None, 'организаций', 'лауреатами', 'премии', 'рунета', 'стали', 'компании', None, 'персоны', 'причем', 'раньше', 'организаторы', 'российская', 'ассоциация', 'электронных', 'коммуникаций', 'раэк', 'награждали', 'несколько', 'лучших', 'представителей', None, 'каждой', None, 'номинации', None, 'мнению', 'экспертного', 'сообщества', None, None, 'году', None, 'обратились', None, 'помощи', 'искусственного', 'интеллекта', None, 'добавили', None, 'одного', 'лауреата', 'который', 'выбирался', 'именно', None, 'мнению', 'ии', 'номинация', 'государство', None, 'общество', 'победители', 'благотворительный', 'фонд', 'подари', 'жизнь', 'ано', 'диалог', 'правительство', 'москвы', 'проект', 'цифровая', 'экосистема', 'москвы', 'фнс', 'россии', 'программа', 'пушкинская', 'карта', 'ао', 'почта', 'банк', 'номинация', 'сми', None, 'массовые', 'коммуникации', 'телеканал', 'медиахолдинг', 'independent', 'media', 'ао', 'коммерсантъ', 'номинация', 'образование', None, 'кадры', 'правительство', 'москвы', 'проект', 'московская', 'электронная', 'школа', 'мэш', 'проект', 'программы', 'сбер', None, 'детей', None, 'родителей', 'совместно', None, 'rambler', 'co', 'ооо', 'цифровое', 'образование', 'проект', 'икоп', 'сферум', 'образовательная', 'платформа', 'нетология', 'ооо', 'нетология', 'компания', 'samsung', 'electronics', 'номинация', 'наука', 'технологии', None, 'инновации', 'gett', 'иннотех', 'skillbox', 'промобот', 'sberdevices', 'билайн', 'номинация', 'культурные', 'проекты', None, 'сети', 'общественное', 'телевидение', 'россии', 'проект', 'путь', 'героя', 'информационного', 'агентства', 'тасс', None, 'киностудии', 'союзмультфильм', 'эмпатия', 'манучи', 'авторский', 'канал', 'манучарова', 'вячеслава', 'федеральное', 'государственное', 'бюджетное', 'учреждение', 'культуры', 'всероссийское', 'музейное', 'объединение', 'государственная', 'третьяковская', 'галерея', 'номинация', 'игровая', 'индустрия', None, 'киберспорт', 'федерация', 'компьютерного', 'спорта', 'города', 'москвы', 'московский', 'киберспорт', 'esforce', 'holding', 'cybersport.metaratings', 'metamma', 'goose', 'gaming', 'номинация', 'креативные', 'индустрии', 'ассоциация', 'профессиональных', 'участников', 'творческой', 'экономики', 'федерация', 'креативных', 'индустрий', 'ооо', 'гэллэри', 'сервис', 'vinci', 'agency', 'проект', None, 'веб-инклюзии', 'студия', 'артемия', 'лебедева', 'номинация', 'здоровье', None, 'медицина', 'здоровье.ру', 'проект', 'здоровое', 'питание', 'федеральная', 'служба', None, 'надзору', None, 'сфере', 'защиты', 'прав', 'потребителей', None, 'благополучия', 'человека', 'правительство', 'москвы', 'проект', None, 'использованию', 'технологий', 'компьютерного', 'зрения', None, 'базе', 'искусственного', 'интеллекта', 'ии', None, 'анализа', 'медицинских', 'изображений', 'номинация', 'экономика', None, 'бизнес', 'сбермаркет', 'balance', 'platform', 'московская', 'биржа', 'метарейтинг', 'номинация', None, 'развитие', 'среднего', None, 'малого', 'бизнеса', None, 'рунете', 'портал', None, 'предпринимателей', 'smallbusiness.ru', 'пао', 'мтс', 'проект', 'знаем', 'лично', 'банк', 'втб', 'пао', 'проект', 'интернет-банк', 'номинация', 'счастьеесть', 'автономная', 'некоммерческая', 'организация', None, 'развитию', 'экологических', 'социальных', None, 'патриотических', 'проектов', 'сад', 'памяти', 'номинация', 'развитие', 'внутреннего', 'туризма', 'проект', 'oh', 'my', 'град', 'россия', 'приключений', 'проект', 'онлайн-медиа', 'russia', 'beyond', 'входящее', None, 'телесеть', 'rt', 'ано', 'проектный', 'офис', None, 'развитию', 'туризма', None, 'гостеприимства', 'москвы', 'туристический', 'сервис', 'russpass', 'комитет', None, 'туризму', 'города', 'москвы', 'проект', 'discovermoscow.com', 'номинация', 'открытые', 'коммуникации', 'мэр', 'вологды', 'сергей', 'воропанов', 'правительство', 'тульской', 'области', 'федеральное', 'агентство', None, 'туризму', 'портал', 'russia.travel', 'народном', 'голосовании', 'премии', 'рунета', None, 'выбраны', 'такие', 'лауреаты', None, 'номинации', None, 'дмитрий', 'спиридонов', None, 'номинации', None, 'forza', None, 'номинациилучший', 'цифровой', 'регион', 'номинация', None, 'город', 'москва', 'вдобавок', None, 'персональный', 'многолетний', 'вклад', None, 'развитие', 'интернет-отрасли', 'награду', 'премия', 'рунета', 'получил', 'экс-глава', 'роспечати', 'михаил', 'сеславинский', None, None, 'году', 'хабр', 'также', 'подавал', 'заявку', None, 'участие', None, 'премии', 'рунета', None, 'номинации', 'креативные', 'индустрии', 'заявлен', None, 'наш', 'конкурс', 'технотекст', None, None, 'стали', 'лауреатами', None, 'вошли', 'сперва', None, 'шорт-лист', None, 'затем', None, None, 'число', 'финалистов', 'рядом', None, 'очень', 'серьёзными', 'соперниками', 'описание', 'заявки', 'хабра', None, 'посмотреть', None, 'странице', 'сайта', 'конкурса']

# %%
tk
# Out:
# ['декабря',
#  'состоялась',
#  'церемония',
#  'награждения',
#  'лауреатов',
#  'премии',
#  'рунета',
#  'года',
#  None,
#  None,
#  'году',
#  None,
#  'премию',
#  None,
#  'подано',
#  'работ',
#  None,
#  'вклад',
#  None,
#  'развитие',
#  'российского',
#  'сегмента',
#  'сети',
#  'интернет',
#  None,
#  'девять',
#  'основных',
#  None,
#  'четыре',
#  'специальные',
#  'номинации',
#  'финалистами',
#  'конкурса',
#  None,
#  'каждой',
#  'номинации',
#  'стали',
#  None,
#  'организаций',
#  'лауреатами',
#  'премии',
#  'рунета',
#  'стали',
#  'компании',
#  None,
#  'персоны',
#  'причем',
#  'раньше',
#  'организаторы',
#  'российская',
#  'ассоциация',
#  'электронных',
#  'коммуникаций',
#  'раэк',
#  'награждали',
#  'несколько',
#  'лучших',
#  'представителей',
#  None,
#  'каждой',
#  None,
#  'номинации',
#  None,
#  'мнению',
#  'экспертного',
#  'сообщества',
#  None,
#  None,
#  'году',
#  None,
#  'обратились',
#  None,
#  'помощи',
#  'искусственного',
# ...

# %%
str = "['декабря', 'состоялась', 'церемония', 'награждения', 'лауреатов', 'премии', 'рунета', 'года', None, None, 'году', None, 'премию', None, 'подано', 'работ', None, 'вклад', None, 'развитие', 'российского', 'сегмента', 'сети', 'интернет', None, 'девять', 'основных', None, 'четыре', 'специальные', 'номинации', 'финалистами', 'конкурса', None, 'каждой', 'номинации', 'стали', None, 'организаций', 'лауреатами', 'премии', 'рунета', 'стали', 'компании', None, 'персоны', 'причем', 'раньше', 'организаторы', 'российская', 'ассоциация', 'электронных', 'коммуникаций', 'раэк', 'награждали', 'несколько', 'лучших', 'представителей', None, 'каждой', None, 'номинации', None, 'мнению', 'экспертного', 'сообщества', None, None, 'году', None, 'обратились', None, 'помощи', 'искусственного', 'интеллекта', None, 'добавили', None, 'одного', 'лауреата', 'который', 'выбирался', 'именно', None, 'мнению', 'ии', 'номинация', 'государство', None, 'общество', 'победители', 'благотворительный', 'фонд', 'подари', 'жизнь', 'ано', 'диалог', 'правительство', 'москвы', 'проект', 'цифровая', 'экосистема', 'москвы', 'фнс', 'россии', 'программа', 'пушкинская', 'карта', 'ао', 'почта', 'банк', 'номинация', 'сми', None, 'массовые', 'коммуникации', 'телеканал', 'медиахолдинг', 'independent', 'media', 'ао', 'коммерсантъ', 'номинация', 'образование', None, 'кадры', 'правительство', 'москвы', 'проект', 'московская', 'электронная', 'школа', 'мэш', 'проект', 'программы', 'сбер', None, 'детей', None, 'родителей', 'совместно', None, 'rambler', 'co', 'ооо', 'цифровое', 'образование', 'проект', 'икоп', 'сферум', 'образовательная', 'платформа', 'нетология', 'ооо', 'нетология', 'компания', 'samsung', 'electronics', 'номинация', 'наука', 'технологии', None, 'инновации', 'gett', 'иннотех', 'skillbox', 'промобот', 'sberdevices', 'билайн', 'номинация', 'культурные', 'проекты', None, 'сети', 'общественное', 'телевидение', 'россии', 'проект', 'путь', 'героя', 'информационного', 'агентства', 'тасс', None, 'киностудии', 'союзмультфильм', 'эмпатия', 'манучи', 'авторский', 'канал', 'манучарова', 'вячеслава', 'федеральное', 'государственное', 'бюджетное', 'учреждение', 'культуры', 'всероссийское', 'музейное', 'объединение', 'государственная', 'третьяковская', 'галерея', 'номинация', 'игровая', 'индустрия', None, 'киберспорт', 'федерация', 'компьютерного', 'спорта', 'города', 'москвы', 'московский', 'киберспорт', 'esforce', 'holding', 'cybersport.metaratings', 'metamma', 'goose', 'gaming', 'номинация', 'креативные', 'индустрии', 'ассоциация', 'профессиональных', 'участников', 'творческой', 'экономики', 'федерация', 'креативных', 'индустрий', 'ооо', 'гэллэри', 'сервис', 'vinci', 'agency', 'проект', None, 'веб-инклюзии', 'студия', 'артемия', 'лебедева', 'номинация', 'здоровье', None, 'медицина', 'здоровье.ру', 'проект', 'здоровое', 'питание', 'федеральная', 'служба', None, 'надзору', None, 'сфере', 'защиты', 'прав', 'потребителей', None, 'благополучия', 'человека', 'правительство', 'москвы', 'проект', None, 'использованию', 'технологий', 'компьютерного', 'зрения', None, 'базе', 'искусственного', 'интеллекта', 'ии', None, 'анализа', 'медицинских', 'изображений', 'номинация', 'экономика', None, 'бизнес', 'сбермаркет', 'balance', 'platform', 'московская', 'биржа', 'метарейтинг', 'номинация', None, 'развитие', 'среднего', None, 'малого', 'бизнеса', None, 'рунете', 'портал', None, 'предпринимателей', 'smallbusiness.ru', 'пао', 'мтс', 'проект', 'знаем', 'лично', 'банк', 'втб', 'пао', 'проект', 'интернет-банк', 'номинация', 'счастьеесть', 'автономная', 'некоммерческая', 'организация', None, 'развитию', 'экологических', 'социальных', None, 'патриотических', 'проектов', 'сад', 'памяти', 'номинация', 'развитие', 'внутреннего', 'туризма', 'проект', 'oh', 'my', 'град', 'россия', 'приключений', 'проект', 'онлайн-медиа', 'russia', 'beyond', 'входящее', None, 'телесеть', 'rt', 'ано', 'проектный', 'офис', None, 'развитию', 'туризма', None, 'гостеприимства', 'москвы', 'туристический', 'сервис', 'russpass', 'комитет', None, 'туризму', 'города', 'москвы', 'проект', 'discovermoscow.com', 'номинация', 'открытые', 'коммуникации', 'мэр', 'вологды', 'сергей', 'воропанов', 'правительство', 'тульской', 'области', 'федеральное', 'агентство', None, 'туризму', 'портал', 'russia.travel', 'народном', 'голосовании', 'премии', 'рунета', None, 'выбраны', 'такие', 'лауреаты', None, 'номинации', None, 'дмитрий', 'спиридонов', None, 'номинации', None, 'forza', None, 'номинациилучший', 'цифровой', 'регион', 'номинация', None, 'город', 'москва', 'вдобавок', None, 'персональный', 'многолетний', 'вклад', None, 'развитие', 'интернет-отрасли', 'награду', 'премия', 'рунета', 'получил', 'экс-глава', 'роспечати', 'михаил', 'сеславинский', None, None, 'году', 'хабр', 'также', 'подавал', 'заявку', None, 'участие', None, 'премии', 'рунета', None, 'номинации', 'креативные', 'индустрии', 'заявлен', None, 'наш', 'конкурс', 'технотекст', None, None, 'стали', 'лауреатами', None, 'вошли', 'сперва', None, 'шорт-лист', None, 'затем', None, None, 'число', 'финалистов', 'рядом', None, 'очень', 'серьёзными', 'соперниками', 'описание', 'заявки', 'хабра', None, 'посмотреть', None, 'странице', 'сайта', 'конкурса']"

res_str = str.replace('None', '') 
# Удаление всех 'None' 
print("Строка после удаления всех символов None: " + res_str)
# Out:
# Строка после удаления всех символов None: ['декабря', 'состоялась', 'церемония', 'награждения', 'лауреатов', 'премии', 'рунета', 'года', , , 'году', , 'премию', , 'подано', 'работ', , 'вклад', , 'развитие', 'российского', 'сегмента', 'сети', 'интернет', , 'девять', 'основных', , 'четыре', 'специальные', 'номинации', 'финалистами', 'конкурса', , 'каждой', 'номинации', 'стали', , 'организаций', 'лауреатами', 'премии', 'рунета', 'стали', 'компании', , 'персоны', 'причем', 'раньше', 'организаторы', 'российская', 'ассоциация', 'электронных', 'коммуникаций', 'раэк', 'награждали', 'несколько', 'лучших', 'представителей', , 'каждой', , 'номинации', , 'мнению', 'экспертного', 'сообщества', , , 'году', , 'обратились', , 'помощи', 'искусственного', 'интеллекта', , 'добавили', , 'одного', 'лауреата', 'который', 'выбирался', 'именно', , 'мнению', 'ии', 'номинация', 'государство', , 'общество', 'победители', 'благотворительный', 'фонд', 'подари', 'жизнь', 'ано', 'диалог', 'правительство', 'москвы'
# ...

# %%
import spacy as f
from spacy import load
from spacy.lang.ru.examples import sentences
from spacy.lang.ru import Russian

# %%
 ! pip install --user pymorphy3

# %% [markdown]
# нужно удалить нон чтобы сработало и будет начальная форма всех слов

# %%
my_list = res_str
for item in my_list:
    print(item.lower())
# Out:
# [
# '
# д
# е
# к
# а
# б
# р
# я
# '
# ,
#
# '
# с
# о
# с
# т
# о
# я
# л
# а
# с
# ь
# '
# ,
#
# '
# ц
# е
# р
# е
# м
# о
# н
# и
# я
# '
# ,
#
# '
# н
# а
# г
# р
# а
# ж
# д
# е
# н
# и
# я
# '
# ,
#
# '
# л
# а
# у
# р
# е
# а
# т
# о
# в
# '
# ,
#
# '
# п
# р
# е
# м
# и
# и
# '
# ,
#
# '
# р
# у
# н
# е
# т
# а
# '
# ,
#
# '
# г
# о
# д
# а
# '
# ,
#
# ,
#
# ,
#
# '
# г
# о
# д
# у
# '
# ,
#
# ,
#
# '
# п
# р
# е
# м
# и
# ю
# '
# ,
#
# ,
#
# '
# п
# о
# д
# а
# н
# о
# '
# ,
#
# '
# р
# а
# б
# о
# т
# '
# ,
#
# ,
#
# '
# в
# к
# л
# а
# д
# '
# ,
#
# ,
#
# '
# р
# а
# з
# в
# и
# т
# и
# е
# '
# ,
#
# '
# р
# о
# с
# с
# и
# й
# с
# к
# о
# г
# о
# '
# ,
#
# '
# с
# е
# г
# м
# е
# н
# т
# а
# '
# ,
#
# '
# с
# е
# т
# и
# '
# ,
#
# '
# и
# н
# т
# е
# р
# н
# е
# т
# '
# ,
#
# ,
#
# '
# д
# е
# в
# я
# т
# ь
# '
# ,
#
# '
# о
# с
# н
# о
# в
# н
# ы
# х
# '
# ,
#
# ,
#
# '
# ч
# е
# т
# ы
# р
# е
# '
# ,
#
# '
# с
# п
# е
# ц
# и
# а
# л
# ь
# н
# ы
# е
# '
# ,
#
# '
# н
# ...

# %%
from pymorphy2 import MorphAnalyzer

morph = MorphAnalyzer()
p = morph.parse(my_list)
p
# Out:
# [Parse(word="['декабря', 'состоялась', 'церемония', 'награждения', 'лауреатов', 'премии', 'рунета', 'года', , , 'году', , 'премию', , 'подано', 'работ', , 'вклад', , 'развитие', 'российского', 'сегмента', 'сети', 'интернет', , 'девять', 'основных', , 'четыре', 'специальные', 'номинации', 'финалистами', 'конкурса', , 'каждой', 'номинации', 'стали', , 'организаций', 'лауреатами', 'премии', 'рунета', 'стали', 'компании', , 'персоны', 'причем', 'раньше', 'организаторы', 'российская', 'ассоциация', 'электронных', 'коммуникаций', 'раэк', 'награждали', 'несколько', 'лучших', 'представителей', , 'каждой', , 'номинации', , 'мнению', 'экспертного', 'сообщества', , , 'году', , 'обратились', , 'помощи', 'искусственного', 'интеллекта', , 'добавили', , 'одного', 'лауреата', 'который', 'выбирался', 'именно', , 'мнению', 'ии', 'номинация', 'государство', , 'общество', 'победители', 'благотворительный', 'фонд', 'подари', 'жизнь', 'ано', 'диалог', 'правительство', 'москвы', 'проект', 'цифровая', 'экос
# ...

# %%
first = p[0]  # первый разбор
print('Лемма:', first.normal_form)
# Out:
# Лемма: ['декабря', 'состоялась', 'церемония', 'награждения', 'лауреатов', 'премии', 'рунета', 'года', , , 'году', , 'премию', , 'подано', 'работ', , 'вклад', , 'развитие', 'российского', 'сегмента', 'сети', 'интернет', , 'девять', 'основных', , 'четыре', 'специальные', 'номинации', 'финалистами', 'конкурса', , 'каждой', 'номинации', 'стали', , 'организаций', 'лауреатами', 'премии', 'рунета', 'стали', 'компании', , 'персоны', 'причем', 'раньше', 'организаторы', 'российская', 'ассоциация', 'электронных', 'коммуникаций', 'раэк', 'награждали', 'несколько', 'лучших', 'представителей', , 'каждой', , 'номинации', , 'мнению', 'экспертного', 'сообщества', , , 'году', , 'обратились', , 'помощи', 'искусственного', 'интеллекта', , 'добавили', , 'одного', 'лауреата', 'который', 'выбирался', 'именно', , 'мнению', 'ии', 'номинация', 'государство', , 'общество', 'победители', 'благотворительный', 'фонд', 'подари', 'жизнь', 'ано', 'диалог', 'правительство', 'москвы', 'проект', 'цифровая', 'экосистема
# ...

# %%
! pip install -U pip setuptools wheel
! pip install -U spacy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 2.1/2.1 MB 4.3 MB/s eta 0:00:00
# ...
#      -------------------------------------- 807.9/807.9 kB 5.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 64.8/64.8 kB 1.8 MB/s eta 0:00:00
# ERROR: To modify pip, please run the following command:
# C:\ProgramData\anaconda3\python.exe -m pip install -U pip setuptools wheel
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
! python -m venv .env
! source .env/bin/activate
! pip install -U pip setuptools wheel
! pip install -U spacy
# Out:
# "source" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: To modify pip, please run the following command:
# C:\ProgramData\anaconda3\python.exe -m pip install -U pip setuptools wheel
# ...
#   Using cached pip-23.2.1-py3-none-any.whl (2.1 MB)
# ...
#   Using cached setuptools-68.2.2-py3-none-any.whl (807 kB)
# ...
#   Using cached wheel-0.41.2-py3-none-any.whl (64 kB)
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %% [markdown]
# разделлить на токены, удалить стоп-слова(наша, их , предлоги, знаки пунктуацииЮ спец символы,) привести к одному регистру(с маленькой буквы, окончания отрезаем)
